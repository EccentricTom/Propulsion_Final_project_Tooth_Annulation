# %% [markdown]
# This notebook extracts the necessary data, both images and metadata, and stores them for ease of use for the other notebooks. As the metadata and images have already been processed, this notebook does not need to be run unless changes have been made to the metadata.

# %% [markdown]
# ####Load these Packages

# %%
import pandas as pd
import numpy as np
import itertools
import os
import glob

# %% [markdown]
# #### Mount Google Drive and specify directory

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount = True)
# Out:
# Mounted at /gdrive

# %%
#Change the working directory to where the project has been saved in google drive
project_dir = "/gdrive/My Drive/Colab Notebooks/TCA_project_Tomek_Thomas/tooth-annulation/"
# Do not change these directories
working_dir = project_dir + "SRC/"
images_dir = project_dir + "data/images_cleaned"
labels_dir = project_dir + 'data'

# %cd {working_dir}
# Out:
# /gdrive/My Drive/Colab Notebooks/TCA_project_Tomek_Thomas/tooth-annulation/SRC

# %% [markdown]
# #### Unzip image folder

# %%
#can only be imported after Google drive has been mounted
import helper as hp
from rename import rename

# %%
#only do this part ONCE, uncomment when need and then re-comment to avoid running the code again.

#hp.unzip_file('./images_final.zip', './data')

# %%
#Check that all images have been unzipped and are in the correct folder.
current_folder_content = glob.glob(images_dir + "/*")
len(current_folder_content)
# Out:
# 2635

# %% [markdown]
# This part looks through the Images folder and creates a list of names for each image and then sorts its alphabetically.

# %%
image_name_list= [] #contain all image names

for image in current_folder_content:
  image_name = image.split('/', 8)[-1]
  image_name_list.append(image_name)

print(len(image_name_list))
image_name_list.sort()
image_name_list[:5]
# Out:
# 2635
# ['001_44_NA_80.25_0138.jpg',
#  '001_44_NA_80.25_0139.tif',
#  '001_44_NA_80.25_0368.jpg',
#  '001_44_NA_80.25_0369.tif',
#  '002_12_2_46_0140.jpg']

# %% [markdown]
# ##### If File names are inconsistent, load this script to batch edit the file extensions. This will avoid errors when trying to load the images in a future notebook.

# %%
rename(images_dir, '*.jpg', ".tif")

# %% [markdown]
# Double check to make sure the remaning has taken place

# %%
current_folder_content = glob.glob(images_dir + "/*")
image_name_list= [] #contain all image names

for image in current_folder_content:
  image_name = image.split('/', 8)[-1]
  image_name_list.append(image_name)

print(len(image_name_list))
image_name_list[:500]
# Out:
# 2635
# ['311_12_2_59.5_2987.tif',
#  '311_11_2_59.5_2982.tif',
#  '310_34_2_76.25_2893.tif',
#  '310_34_2_76.25_2892.tif',
#  '310_34_2_76.25_2891.tif',
#  '308_22_1_54.25_2806.tif',
#  '308_22_1_54.25_2805.tif',
#  '307_21_2_67_3012.tif',
#  '307_21_2_67_3016.tif',
#  '307_21_2_67_2804.tif',
#  '307_21_2_67_2803.tif',
#  '307_21_2_67_2802.tif',
#  '305_32_1_58_3019.tif',
#  '305_32_1_58_2699.tif',
#  '305_32_1_58_2698.tif',
#  '305_32_1_58_2697.tif',
#  '304_32_1_63.25_3005.tif',
#  '304_32_1_63.25_2694.tif',
#  '304_32_1_63.25_2693.tif',
#  '303_32_2_57_3003.tif',
#  '303_32_2_57_3001.tif',
#  '303_32_2_57_2690.tif',
#  '303_32_2_57_2688.tif',
#  '303_32_2_57_2687.tif',
#  '303_32_2_57_2684.tif',
#  '302_31_2_57_2499.tif',
#  '302_31_2_57_2498.tif',
#  '302_31_2_57_2403.tif',
#  '302_31_2_57_2402.tif',
#  '302_31_2_57_2401.tif',
#  '302_31_2_57_2400.tif',
#  '301_41_2_57_2397.tif',
#  '301_41_2_57_2380.tif',
#  '300_22_2_46.75_3445.tif',
#  '300_22_2_46.75_3233.tif',
#  '300_22_2_46.75_3206.tif',
#  '300_22_2_46.75_3202.tif',
#  '300_21_2_46.75_2494.tif',
#  '300_21_2_46.75_2378.tif',
#  '300_21_2_46.75_2355.tif',
#  '300_21_2_46.75_2354.tif',
#  '300_12_2_46.75_2281.tif',
#  '300_12_2_46.75_2237.tif',
#  '300_12_2_46.75_2236.tif',
#  '300_12_2_46.75_2235.tif',
#  '300_12_2_46.75_2234.tif',
#  '300_11_2_46.75_2279.tif',
#  '300_12_2_46.75_2233.tif',
#  '300_11_2_46.75_2278.tif',
#  '300_11_2_46.75_2232.tif',
#  '300_11_2_46.75_2231.tif',
#  '300_11_2_46.75_2229.tif',
#  '299_15_2_72_3916.tif',
#  '299_15_2_72_3889.tif',
#  '299_15_2_72_3887.tif',
#  '299_15_2_72_3915.tif',
#  '299_15_2_72_3886.tif',
#  '299_15_2_72_3891.tif',
#  '299_15_2_72_3884.tif',
#  '298_43_1_59.75_3896.tif',
#  '298_43_1_59.75_3895.tif',
#  '298_43_1_59.75_3893.tif',
#  '289_41_2_59.25_3934.tif',
#  '289_41_2_59.25_3928.tif',
#  '288_42_2_59_3921.tif',
#  '288_42_2_59_3917.tif',
#  '288_42_2_59_3913.tif',
#  '287_45_2_58.75_3794.tif',
#  '287_45_2_58.75_3756.tif',
#  '287_45_2_58.75_3755.tif',
#  '287_45_2_58.75_3754.tif',
#  '287_45_2_58.75_3753.tif',
#  '286_44_2_58.75_3793.tif',
#  '286_44_2_58.75_3752.tif',
#  '286_44_2_58.75_3751.tif',
#  '286_44_2_58.75_3749.tif',
#  '286_44_2_58.75_3750.tif',
#  '286_44_2_58.75_3748.tif',
#  '286_44_2_58.75_3747.tif',
#  '285_42_2_58.75_3830.tif',
#  '285_42_2_58.75_3829.tif',
#  '285_42_2_58.75_3827.tif',
#  '285_42_2_58.75_3826.tif',
#  '285_42_2_58.75_3825.tif',
#  '285_42_2_58.75_3746.tif',
#  '285_42_2_58.75_3743.tif',
#  '285_42_2_58.75_3742.tif',
#  '282_21_2_60.5_3741.tif',
#  '282_21_2_60.5_3792.tif',
#  '282_21_2_60.5_3739.tif',
#  '282_21_2_60.5_3738.tif',
#  '282_12_2_60.5_3366.tif',
#  '282_11_2_60.5_3790.tif',
#  '282_11_2_60.5_3789.tif',
#  '282_11_2_60.5_3363.tif',
#  '282_11_2_60.5_3362.tif',
#  '282_11_2_60.5_3361.tif',
#  '274_35_1_19.5_3100.tif',
#  '274_35_1_19.5_3230.tif',
#  '274_35_1_19.5_3099.tif',
#  '273_12_1_62.75_6187.tif',
#  '273_12_1_62.75_3229.tif',
#  '273_12_1_62.75_3094.tif',
#  '271_14_1_12.25_3091.tif',
#  '271_14_1_12.25_3090.tif',
#  '270_44_1_67.75_6094.tif',
#  '270_44_1_67.75_3068.tif',
#  '270_44_1_67.75_3067.tif',
#  '270_44_1_67.75_3066.tif',
#  '270_44_1_67.75_0164.tif',
#  '270_44_1_67.75_0136.tif',
#  '270_44_1_67.75_0135.tif',
#  '270_44_1_67.75_0134.tif',
#  '269_34_2_57.75_3227.tif',
#  '269_34_2_57.75_3065.tif',
#  '268_35_2_57.75_2815.tif',
#  '267_33_2_57.75_3225.tif',
#  '267_33_2_57.75_2813.tif',
#  '267_33_2_57.75_2811.tif',
#  '265_22_2_57.75_3222.tif',
#  '265_22_2_57.75_2761.tif',
#  '265_22_2_57.75_3221.tif',
#  '265_22_2_57.75_2760.tif',
#  '265_22_2_57.75_2759.tif',
#  '261_45_2_64_3220.tif',
#  '261_45_2_64_2651.tif',
#  '261_44_2_64_3219.tif',
#  '261_44_2_64_2626.tif',
#  '261_21_2_64_2467.tif',
#  '261_21_2_64_2466.tif',
#  '261_21_2_64_2445.tif',
#  '261_21_2_64_2444.tif',
#  '261_21_2_64_2442.tif',
#  '261_21_2_64_2440.tif',
#  '261_11_2_64_2465.tif',
#  '261_11_2_64_2417.tif',
#  '261_11_2_64_2416.tif',
#  '261_11_2_64_2412.tif',
#  '261_11_2_64_2414.tif',
#  '259_35_2_31.75_2463.tif',
#  '259_35_2_31.75_2410.tif',
#  '259_35_2_31.75_2409.tif',
#  '259_35_2_31.75_2408.tif',
#  '259_35_2_31.75_2405.tif',
#  '259_35_2_31.75_2404.tif',
#  '257_44_2_64.75_2364.tif',
#  '256_25_2_54.75_2358.tif',
#  '256_25_2_54.75_2352.tif',
#  '255_44_2_48.75_2457.tif',
#  '255_44_2_48.75_2456.tif',
#  '255_44_2_48.75_2350.tif',
#  '255_44_2_48.75_2349.tif',
#  '255_44_2_48.75_2348.tif',
#  '255_44_2_48.75_2347.tif',
#  '254_11_2_35.5_3453.tif',
#  '254_11_2_35.5_2277.tif',
#  '254_11_2_35.5_2276.tif',
#  '254_11_2_35.5_2274.tif',
#  '254_11_2_35.5_2225.tif',
#  '254_11_2_35.5_2224.tif',
#  '254_11_2_35.5_2114.tif',
#  '253_22_2_68.25_1966.tif',
#  '251_22_2_58.75_7212.tif',
#  '251_22_2_58.75_7211.tif',
#  '251_22_2_58.75_2198.tif',
#  '251_21_2_58.75_7210.tif',
#  '251_22_2_58.75_1946.tif',
#  '251_21_2_58.75_7208.tif',
#  '251_21_2_58.75_2263.tif',
#  '251_21_2_58.75_2178.tif',
#  '251_21_2_58.75_2262.tif',
#  '251_21_2_58.75_2177.tif',
#  '251_21_2_58.75_1959.tif',
#  '250_45_1_48.5_3214.tif',
#  '246_31_1_48.5_3185.tif',
#  '246_31_1_48.5_3083.tif',
#  '246_31_1_48.5_3082.tif',
#  '245_12_2_50_3085.tif',
#  '243_32_1_48.5_3169.tif',
#  '243_32_1_48.5_3134.tif',
#  '243_32_1_48.5_3133.tif',
#  '242_41_1_48.5_3168.tif',
#  '242_41_1_48.5_3167.tif',
#  '242_41_1_48.5_3138.tif',
#  '242_41_1_48.5_3137.tif',
#  '242_41_1_48.5_3135.tif',
#  '242_41_1_48.5_3136.tif',
#  '241_21_2_68.25_3346.tif',
#  '239_12_2_68.25_3476.tif',
#  '239_12_2_68.25_3355.tif',
#  '239_12_2_68.25_3354.tif',
#  '239_12_2_68.25_3353.tif',
#  '239_12_2_68.25_3352.tif',
#  '238_22_1_48.5_3475.tif',
#  '238_22_1_48.5_3473.tif',
#  '238_22_1_48.5_3360.tif',
#  '238_22_1_48.5_3359.tif',
#  '238_22_1_48.5_3358.tif',
#  '236_32_1_88.5_6185.tif',
#  '236_32_1_88.5_6183.tif',
#  '236_32_1_88.5_6171.tif',
#  '236_32_1_88.5_6147.tif',
#  '236_32_1_88.5_6146.tif',
#  '236_32_1_88.5_6145.tif',
#  '236_32_1_88.5_6144.tif',
#  '236_32_1_88.5_6143.tif',
#  '236_32_1_88.5_6142.tif',
#  '236_32_1_88.5_0169.tif',
#  '236_32_1_88.5_0435.tif',
#  '236_32_1_88.5_0168.tif',
#  '236_32_1_88.5_0133.tif',
#  '236_32_1_88.5_0129.tif',
#  '236_32_1_88.5_0128.tif',
#  '235_42_1_48.5_3506.tif',
#  '235_42_1_48.5_3389.tif',
#  '235_42_1_48.5_3388.tif',
#  '233_11_2_68.25_3493.tif',
#  '233_11_2_68.25_3491.tif',
#  '233_11_2_68.25_3488.tif',
#  '233_11_2_68.25_3405.tif',
#  '233_11_2_68.25_3404.tif',
#  '233_11_2_68.25_3402.tif',
#  '233_11_2_68.25_3401.tif',
#  '233_11_2_68.25_3400.tif',
#  '233_11_2_68.25_3399.tif',
#  '233_11_2_68.25_3398.tif',
#  '232_31_2_49_2454.tif',
#  '232_31_2_49_2375.tif',
#  '232_31_2_49_2374.tif',
#  '231_32_2_46_3412.tif',
#  '231_31_2_46_3518.tif',
#  '231_31_2_46_3425.tif',
#  '231_31_2_46_3424.tif',
#  '231_31_2_46_3421.tif',
#  '230_23_2_51.75_3430.tif',
#  '231_31_2_46_3420.tif',
#  '229_42_2_63.5_3583.tif',
#  '229_42_2_63.5_3582.tif',
#  '229_42_2_63.5_3580.tif',
#  '229_42_2_63.5_3568.tif',
#  '229_42_2_63.5_3567.tif',
#  '229_42_2_63.5_3565.tif',
#  '229_42_2_63.5_3564.tif',
#  '229_42_2_63.5_3562.tif',
#  '229_42_2_63.5_3560.tif',
#  '229_41_2_63.5_3574.tif',
#  '229_41_2_63.5_3573.tif',
#  '229_41_2_63.5_3572.tif',
#  '229_41_2_63.5_3559.tif',
#  '229_41_2_63.5_3558.tif',
#  '010_35_NA_63.25_0396.png',
#  'Image_location.txt',
#  '090_34_2_60_1013.tif',
#  '090_34_2_60_1014.tif',
#  '090_34_2_60_1015.tif',
#  '090_34_2_60_1017.tif',
#  '090_34_2_60_1018.tif',
#  '090_34_2_60_1019.tif',
#  '090_34_2_60_1020.tif',
#  '090_34_2_60_1024.tif',
#  '090_34_2_60_1025.tif',
#  '090_34_2_60_1026.tif',
#  '094_33_2_87.75_01.tif',
#  '094_33_2_87.75_1027.tif',
#  '094_33_2_87.75_1028.tif',
#  '094_33_2_87.75_1029.tif',
#  '094_33_2_87.75_1030.tif',
#  '094_33_2_87.75_1031.tif',
#  '094_33_2_87.75_1032.tif',
#  '094_33_2_87.75_1033.tif',
#  '094_33_2_87.75_1034.tif',
#  '094_33_2_87.75_1035.tif',
#  '094_33_2_87.75_1036.tif',
#  '094_33_2_87.75_1044.tif',
#  '094_33_2_87.75_1045.tif',
#  '094_33_2_87.75_1046.tif',
#  '094_33_2_87.75_1047.tif',
#  '094_33_2_87.75_6194.tif',
#  '094_33_2_87.75_6196.tif',
#  '094_33_2_87.75_6198.tif',
#  '094_33_2_87.75_6200.tif',
#  '094_33_2_87.75_6202.tif',
#  '094_33_2_87.75_6407.tif',
#  '096_14_2_59.75_1038.tif',
#  '096_14_2_59.75_1039.tif',
#  '096_14_2_59.75_1040.tif',
#  '096_14_2_59.75_1041.tif',
#  '096_14_2_59.75_1042.tif',
#  '096_14_2_59.75_1043.tif',
#  '096_14_2_59.75_1048.tif',
#  '096_14_2_59.75_1049.tif',
#  '096_14_2_59.75_1050.tif',
#  '096_14_2_59.75_1051.tif',
#  '098_34_2_72_0209.tif',
#  '098_34_2_72_0210.tif',
#  '098_34_2_72_0211.tif',
#  '098_34_2_72_0212.tif',
#  '098_34_2_72_0213.tif',
#  '098_34_2_72_0214.tif',
#  '098_34_2_72_0215.tif',
#  '098_34_2_72_0216.tif',
#  '098_34_2_72_0275.tif',
#  '099_15_2_61.75_1052.tif',
#  '099_15_2_61.75_1053.tif',
#  '099_15_2_61.75_1054.tif',
#  '099_15_2_61.75_1055.tif',
#  '099_15_2_61.75_1056.tif',
#  '099_15_2_61.75_1057.tif',
#  '099_15_2_61.75_1058.tif',
#  '099_15_2_61.75_1059.tif',
#  '099_15_2_61.75_1060.tif',
#  '099_15_2_61.75_1084.tif',
#  '099_15_2_61.75_1085.tif',
#  '099_15_2_61.75_1086.tif',
#  '099_25_2_61.75_1061.tif',
#  '099_25_2_61.75_1062.tif',
#  '099_25_2_61.75_1063.tif',
#  '099_25_2_61.75_1064.tif',
#  '099_25_2_61.75_1065.tif',
#  '099_25_2_61.75_1066.tif',
#  '099_25_2_61.75_1067.tif',
#  '099_25_2_61.75_1068.tif',
#  '099_25_2_61.75_1087.tif',
#  '099_25_2_61.75_1088.tif',
#  '099_25_2_61.75_1089.tif',
#  '100_11_2_64.75_1091.tif',
#  '100_11_2_64.75_1093.tif',
#  '100_11_2_64.75_1108.tif',
#  '101_32_2_72_0217.tif',
#  '101_32_2_72_0218.tif',
#  '101_32_2_72_0219.tif',
#  '101_32_2_72_0220.tif',
#  '101_32_2_72_0221.tif',
#  '101_32_2_72_0222.tif',
#  '101_32_2_72_0223.tif',
#  '101_32_2_72_0224.tif',
#  '101_32_2_72_0225.tif',
#  '101_32_2_72_0276.tif',
#  '101_32_2_72_0277.tif',
#  '102_44_2_13_1109.tif',
#  '102_44_2_13_1110.tif',
#  '102_44_2_13_1111.tif',
#  '105_11_2_70.5_0226.tif',
#  '343_35_1_48.5_3808.tif',
#  '353_15_2_62.25_2506.tif',
#  '357_11_1_44.25_2486.tif',
#  '357_11_1_44.25_2489.tif',
#  '357_11_1_44.25_2832.tif',
#  '357_11_1_44.25_2833.tif',
#  '357_12_1_44.25_2480.tif',
#  '357_12_1_44.25_2481.tif',
#  '362_44_2_73.5_2558.tif',
#  '362_44_2_73.5_2869.tif',
#  '364_31_1_79.5_2560.tif',
#  '364_31_1_79.5_2561.tif',
#  '364_31_1_79.5_2880.tif',
#  '364_32_1_79.5_2582.tif',
#  '364_32_1_79.5_2583.tif',
#  '364_32_1_79.5_2879.tif',
#  '364_41_1_79.5_2585.tif',
#  '364_41_1_79.5_2588.tif',
#  '364_41_1_79.5_2884.tif',
#  '364_42_1_79.5_2590.tif',
#  '364_42_1_79.5_2592.tif',
#  '364_42_1_79.5_2593.tif',
#  '364_42_1_79.5_2886.tif',
#  '366_32_1_60.5_2630.tif',
#  '366_32_1_60.5_2631.tif',
#  '368_41_1_60.5_6150.tif',
#  '368_41_1_60.5_6189.tif',
#  '388_14_1_42_2709.tif',
#  '389_33_1_66_2710.tif',
#  '389_33_1_66_2711.tif',
#  '389_33_1_66_2713.tif',
#  '390_35_1_25_2740.tif',
#  '393_31_1_62_2838.tif',
#  '393_31_1_62_2962.tif',
#  '394_11_1_63.75_2845.tif',
#  '394_11_1_63.75_2964.tif',
#  '395_12_1_63.75_2847.tif',
#  '395_12_1_63.75_2849.tif',
#  '395_12_1_63.75_2851.tif',
#  '395_12_1_63.75_2968.tif',
#  '396_22_1_63.75_2852.tif',
#  '397_42_1_66_2916.tif',
#  '397_42_1_66_2918.tif',
#  '405_32_2_51_2572.tif',
#  '405_32_2_51_2985.tif',
#  '409_42_1_60_3272.tif',
#  '410_31_1_60_2609.tif',
#  '410_31_1_60_3276.tif',
#  '413_41_2_51_2617.tif',
#  '540_12_1_44_3833.tif',
#  '492_42_1_68.5_4042.tif',
#  '492_42_1_68.5_4026.tif',
#  '491_43_1_68.5_4025.tif',
#  '475_44_2_66.5_3989.tif',
#  '493_31_1_68.5_4033.tif',
#  '493_31_1_68.5_4032.tif',
#  '475_44_2_66.5_3986.tif',
#  '475_44_2_66.5_3985.tif',
#  '474_43_2_75.5_3983.tif',
#  '474_43_2_75.5_3977.tif',
#  '474_43_2_75.5_3974.tif',
#  '474_43_2_75.5_3973.tif',
#  '474_43_2_75.5_3968.tif',
#  '474_43_2_75.5_3966.tif',
#  '474_43_2_75.5_3964.tif',
#  '474_43_2_75.5_3956.tif',
#  '474_43_2_75.5_3955.tif',
#  '471_12_2_62_3952.tif',
#  '471_12_2_62_3906.tif',
#  '471_12_2_62_3904.tif',
#  '470_22_2_41_3963.tif',
#  '470_22_2_41_3962.tif',
#  '470_22_2_41_3901.tif',
#  '470_22_2_41_3900.tif',
#  '470_22_2_41_3899.tif',
#  '470_22_2_41_3898.tif',
#  '469_32_2_63.25_3944.tif',
#  '469_32_2_63.25_3847.tif',
#  '468_42_2_63.25_3943.tif',
#  '468_42_2_63.25_3846.tif',
#  '468_42_2_63.25_3844.tif',
#  '468_42_2_63.25_3842.tif',
#  '467_12_1_32.75_3839.tif',
#  '465_41_1_50.5_3728.tif',
#  '465_41_1_50.5_3727.tif',
#  '465_41_1_50.5_3726.tif',
#  '465_33_1_50.5_3694.tif',
#  '465_32_1_50.5_3733.tif',
#  '465_32_1_50.5_3732.tif',
#  '465_31_1_50.5_3698.tif',
#  '465_31_1_50.5_3697.tif',
#  '464_23_1_59.75_3692.tif',
#  '464_23_1_59.75_3690.tif',
#  '464_23_1_59.75_3688.tif',
#  '463_15_2_49.5_3862.tif',
#  '463_15_2_49.5_3686.tif',
#  '462_13_2_43.5_3861.tif',
#  '462_13_2_43.5_3681.tif',
#  '462_13_2_43.5_3680.tif',
#  '461_41_2_63.75_3657.tif',
#  '461_41_2_63.75_3656.tif',
#  '461_31_2_63.75_3652.tif',
#  '461_31_2_63.75_3651.tif',
#  '461_31_2_63.75_3650.tif',
#  '457_42_1_57.75_3458.tif',
#  '457_42_1_57.75_3457.tif',
#  '457_42_1_57.75_3456.tif',
#  '457_35_1_57.75_3375.tif',
#  '457_35_1_57.75_3373.tif',
#  '457_32_1_57.75_3372.tif',
#  '457_32_1_57.75_3371.tif',
#  '457_32_1_57.75_3370.tif',
#  '457_32_1_57.75_3369.tif',
#  '457_32_1_57.75_3367.tif',
#  '456_43_2_80.5_3247.tif',
#  '448_24_2_15_3241.tif',
#  '448_24_2_15_3240.tif',
#  '448_24_2_15_3239.tif',
#  '445_32_2_53.75_3336.tif',
#  '445_32_2_53.75_3335.tif',
#  '445_32_2_53.75_3157.tif',
#  '445_32_2_53.75_3156.tif',
#  '445_32_2_53.75_3155.tif',
#  '444_41_2_54.75_3334.tif',
#  '444_41_2_54.75_3333.tif',
#  '444_41_2_54.75_3332.tif',
#  '444_41_2_54.75_3331.tif',
#  '444_41_2_54.75_3146.tif',
#  '444_41_2_54.75_3145.tif',
#  '444_41_2_54.75_3144.tif',
#  '444_41_2_54.75_3143.tif',
#  '443_34_1_52.74_3072.tif',
#  '439_45_2_50.5_3325.tif',
#  '439_45_2_50.5_3323.tif',
#  '439_45_2_50.5_3013.tif',
#  '439_45_2_50.5_3011.tif',
#  '439_45_2_50.5_3006.tif',
#  '437_31_2_53.75_3321.tif',
#  '437_31_2_53.75_3320.tif',
#  '437_31_2_53.75_3319.tif',
#  '437_31_2_53.75_2996.tif',
#  '437_31_2_53.75_2995.tif',
#  '437_31_2_53.75_2994.tif',
#  '437_31_2_53.75_2993.tif',
#  '437_31_2_53.75_2992.tif',
#  '436_45_2_54.75_3318.tif',
#  '436_45_2_54.75_3317.tif',
#  '436_45_2_54.75_2948.tif',
#  '436_45_2_54.75_2947.tif',
#  '436_45_2_54.75_2945.tif',
#  '436_45_2_54.75_2875.tif',
#  '434_41_2_53.75_2795.tif',
#  '434_41_2_53.75_2794.tif',
#  '433_22_2_45.75_3313.tif',
#  '433_22_2_45.75_2792.tif',
#  '433_22_2_45.75_2789.tif',
#  '433_22_2_45.75_2788.tif']

# %% [markdown]
# #### Check out the metadata

# %% [markdown]
# Read the metadata file

# %%
meta = pd.read_excel(labels_dir + "/Metadata_clean.xlsx")
extra_meta = pd.read_excel(labels_dir + '/Datentabelle TCA_in-Arbeit.xlsx')
meta.head()
# Out:
#    ID  Tooth.Code    Age  Sex  ImgID                   ImgName
# 0   1        44.0  80.25  NaN    138  001_44_NA_80.25_0138.jpg
# 1   1        44.0  80.25  NaN    139  001_44_NA_80.25_0139.jpg
# 2   1        44.0  80.25  NaN    368  001_44_NA_80.25_0368.tif
# 3   1        44.0  80.25  NaN    369  001_44_NA_80.25_0369.tif
# 4   2        12.0  46.00  2.0    140      002_12_2_46_0140.jpg

# %% [markdown]
# Some data is missing, we can add this from the "Datentabelle TCA_in-Arbeit" file

# %%
extra_meta = extra_meta.loc[:, ['ID','tooth code', 'eruption']]
print(extra_meta.shape)
extra_meta.head()
# Out:
# (583, 3)
#    ID  tooth code  eruption
# 0   1        44.0      10.0
# 1   2        12.0       8.5
# 2   3        42.0       8.5
# 3   5        21.0       7.5
# 4   6        22.0       8.5

# %%
print(meta.shape)
print(meta.isna().sum())
# Out:
# (2634, 6)
# ID             0
# Tooth.Code    41
# Age           70
# Sex           83
# ImgID          0
# ImgName        0
# dtype: int64

# %% [markdown]
# There are some missing values for sex and tooth code. Rather than remove them, the mising values are filled with the number "0".

# %%
meta[['Tooth.Code', 'Sex']] = meta[['Tooth.Code', 'Sex']].fillna(value = 0)
clean_meta = meta.dropna()
print(clean_meta.shape)
clean_meta.head(10)
# Out:
# (2564, 6)
#    ID  Tooth.Code    Age  Sex  ImgID                   ImgName
# 0   1        44.0  80.25  0.0    138  001_44_NA_80.25_0138.jpg
# 1   1        44.0  80.25  0.0    139  001_44_NA_80.25_0139.jpg
# 2   1        44.0  80.25  0.0    368  001_44_NA_80.25_0368.tif
# 3   1        44.0  80.25  0.0    369  001_44_NA_80.25_0369.tif
# 4   2        12.0  46.00  2.0    140      002_12_2_46_0140.jpg
# 5   2        12.0  46.00  2.0    141      002_12_2_46_0141.jpg
# 6   2        12.0  46.00  2.0    142      002_12_2_46_0142.jpg
# 7   2        12.0  46.00  2.0    143      002_12_2_46_0143.jpg
# 8   2        12.0  46.00  2.0    144      002_12_2_46_0144.jpg
# 9   2        12.0  46.00  2.0    151      002_12_2_46_0151.jpg

# %% [markdown]
# The data is now ready to be merged together. Duplicate images also need to be removed, which is done in the code below.

# %%
merged_meta = pd.merge(clean_meta, extra_meta, left_on = ['ID', 'Tooth.Code'], right_on = ["ID", "tooth code"], how = "inner")
merged_meta = merged_meta.drop_duplicates("ImgName")
print(merged_meta.shape)
merged_meta.head()
# Out:
# (2564, 8)
#    ID  Tooth.Code    Age  ...                   ImgName  tooth code eruption
# 0   1        44.0  80.25  ...  001_44_NA_80.25_0138.jpg        44.0     10.0
# 1   1        44.0  80.25  ...  001_44_NA_80.25_0139.jpg        44.0     10.0
# 2   1        44.0  80.25  ...  001_44_NA_80.25_0368.tif        44.0     10.0
# 3   1        44.0  80.25  ...  001_44_NA_80.25_0369.tif        44.0     10.0
# 4   2        12.0  46.00  ...      002_12_2_46_0140.jpg        12.0      8.5
#
# [5 rows x 8 columns]

# %% [markdown]
# Rename any file extensions which do not fit the renamed files

# %%
merged_meta[['ImgName']] = merged_meta[['ImgName']].replace({'.jpg':'.tif'}, regex = True)

# %% [markdown]
# Make sure that only the images in the folder are in the table

# %%
merged_meta = merged_meta[merged_meta["ImgName"].isin(image_name_list)]

# %%
merged_meta = merged_meta.drop('tooth code', axis = 1)
merged_meta.head()
# Out:
#    ID  Tooth.Code    Age  Sex  ImgID                   ImgName  eruption
# 0   1        44.0  80.25  0.0    138  001_44_NA_80.25_0138.tif      10.0
# 1   1        44.0  80.25  0.0    139  001_44_NA_80.25_0139.tif      10.0
# 2   1        44.0  80.25  0.0    368  001_44_NA_80.25_0368.tif      10.0
# 3   1        44.0  80.25  0.0    369  001_44_NA_80.25_0369.tif      10.0
# 4   2        12.0  46.00  2.0    140      002_12_2_46_0140.tif       8.5

# %% [markdown]
# Once the table is nice and clean, export as a CSV file for future use

# %%
with open(project_dir +'data/clean_meta.csv', 'w') as f:
  merged_meta.to_csv(f)
